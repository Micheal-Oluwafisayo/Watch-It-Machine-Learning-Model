# %% [markdown]
# <a href="https://colab.research.google.com/github/Micheal-Oluwafisayo/Watch-It-Machine-Learning-Model/blob/main/Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report, f1_score

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Load the datasets

train_df = pd.read_csv('/content/drive/MyDrive/Case Study/Copy of train.csv')
test_df = pd.read_csv('/content/drive/MyDrive/Case Study/Copy of test.csv')

# %%
# Display the first few rows of the training dataset
train_df.head()
# Out:
#                                  title      country  \
# 0              Pooh's Heffalump Movie           USA
# 1             Yeh Jawaani Hai Deewani         India
# 2  Tae Guk Gi: The Brotherhood of War   South Korea
# 3                    Book of Eli, The           USA
# 4                        Blind Dating           USA
#
#                                               genres                language  \
# 0  Animation, Comedy, Family, Fantasy, Musical, M...                 English
# 1                    Comedy, Drama, Musical, Romance  Hindi, English, French
# 2                                 Action, Drama, War                  Korean
# 3                 Action, Adventure, Drama, Thriller                 English
# 4                                    Comedy, Romance                 English
#
#    writer_count  title_adaption censor_rating release_date  runtime  \
# 0           3.0            True             G    11-Feb-05   68 min
# 1           2.0            True     Not Rated    31-May-13  160 min
# 2           4.0           False             R    24-Sep-04  140 min
# 3           1.0           False             R    15-Jan-10  118 min
# 4           1.0           False         PG-13    26-Apr-07   95 min
#
#   dvd_release_date  ...  likes  overall_views  dislikes  ratings_imdb  \
# 0        24-May-05  ...    NaN            NaN       NaN        6.4/10
# 1        15-Jul-13  ...  124.0       127528.0      12.0        7.1/10
# 2        15-Feb-05  ...  614.0       351123.0      18.0        8.1/10
# 3        15-Jun-10  ...    NaN            NaN       NaN        6.9/10
# 4        05-Feb-08  ...  693.0       970306.0      36.0        6.1/10
#
#    ratings_tomatoes ratings_metacritic special_award awards_win  \
# 0               80%             64/100             0          0
# 1               67%                  0             0         22
# 2               80%             64/100             0         12
# 3               47%             53/100             0          3
# 4               25%                  0             0          0
#
#    awards_nomination  revenue_category
# 0                  1              High
# 1                 92               Low
# 2                  7               Low
# 3                 16              High
# 4                  0               Low
#
# [5 rows x 22 columns]

# %%
# Check for missing values in the dataset
missing_values = train_df.isnull().sum()

# Check data types and basic statistics
data_info = train_df.info()
data_description = train_df.describe(include="all")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2400 entries, 0 to 2399
# Data columns (total 22 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   title               2398 non-null   object
#  1   country             2400 non-null   object
#  2   genres              2400 non-null   object
#  3   language            2395 non-null   object
#  4   writer_count        2306 non-null   float64
#  5   title_adaption      2400 non-null   bool
#  6   censor_rating       2362 non-null   object
#  7   release_date        2396 non-null   object
#  8   runtime             2400 non-null   object
#  9   dvd_release_date    2331 non-null   object
#  10  users_votes         2400 non-null   object
#  11  comments            1974 non-null   float64
#  12  likes               1956 non-null   float64
#  13  overall_views       2083 non-null   float64
#  14  dislikes            1956 non-null   float64
#  15  ratings_imdb        2400 non-null   object
#  16  ratings_tomatoes    2400 non-null   object
#  17  ratings_metacritic  2400 non-null   object
#  18  special_award       2400 non-null   int64
#  19  awards_win          2400 non-null   int64
#  20  awards_nomination   2400 non-null   int64
#  21  revenue_category    2400 non-null   object
# dtypes: bool(1), float64(5), int64(3), object(13)
# memory usage: 396.2+ KB

# %%
missing_values, data_info, data_description
# Out:
# (title                   2
#  country                 0
#  genres                  0
#  language                5
#  writer_count           94
#  title_adaption          0
#  censor_rating          38
#  release_date            4
#  runtime                 0
#  dvd_release_date       69
#  users_votes             0
#  comments              426
#  likes                 444
#  overall_views         317
#  dislikes              444
#  ratings_imdb            0
#  ratings_tomatoes        0
#  ratings_metacritic      0
#  special_award           0
#  awards_win              0
#  awards_nomination       0
#  revenue_category        0
#  dtype: int64,
#  None,
#                    title country genres language  writer_count title_adaption  \
#  count              2398    2400   2400     2395   2306.000000           2400
#  unique             2387     485    586      474           NaN              2
#  top     Last Kiss, The      USA  Drama  English           NaN          False
#  freq                  2    1185    147     1313           NaN           1202
#  mean                NaN     NaN    NaN      NaN      2.596271            NaN
#  std                 NaN     NaN    NaN      NaN      2.011586            NaN
#  min                 NaN     NaN    NaN      NaN      1.000000            NaN
#  25%                 NaN     NaN    NaN      NaN      1.000000            NaN
#  50%                 NaN     NaN    NaN      NaN      2.000000            NaN
#  75%                 NaN     NaN    NaN      NaN      3.000000            NaN
#  max                 NaN     NaN    NaN      NaN     28.000000            NaN
#
#         censor_rating release_date runtime dvd_release_date  ...  \
#  count           2362         2396    2400             2331  ...
#  unique             8         1216     116              898  ...
#  top                R    27-Apr-12  90 min        12-Jan-10  ...
#  freq             971            8      92               10  ...
#  mean             NaN          NaN     NaN              NaN  ...
#  std              NaN          NaN     NaN              NaN  ...
#  min              NaN          NaN     NaN              NaN  ...
#  25%              NaN          NaN     NaN              NaN  ...
#  50%              NaN          NaN     NaN              NaN  ...
#  75%              NaN          NaN     NaN              NaN  ...
#  max              NaN          NaN     NaN              NaN  ...
#
#                  likes  overall_views      dislikes  ratings_imdb  \
#  count     1956.000000   2.083000e+03   1956.000000          2400
#  unique            NaN            NaN           NaN            69
#  top               NaN            NaN           NaN        6.6/10
#  freq              NaN            NaN           NaN           117
#  mean      3113.894172   1.345472e+06    232.665644           NaN
#  std      10213.600411   4.030918e+06    946.288417           NaN
#  min          0.000000   2.100000e+01      0.000000           NaN
#  25%         99.000000   6.752950e+04      7.000000           NaN
#  50%        425.000000   2.816520e+05     30.000000           NaN
#  75%       1819.000000   9.855095e+05    121.250000           NaN
#  max     188526.000000   1.071502e+08  29267.000000           NaN
#
#          ratings_tomatoes ratings_metacritic special_award   awards_win  \
#  count               2400               2400   2400.000000  2400.000000
#  unique               102                 94           NaN          NaN
#  top                  85%                  0           NaN          NaN
#  freq                  50                114           NaN          NaN
#  mean                 NaN                NaN      0.185417     6.582917
#  std                  NaN                NaN      0.388716    16.089857
#  min                  NaN                NaN      0.000000     0.000000
#  25%                  NaN                NaN      0.000000     0.000000
#  50%                  NaN                NaN      0.000000     2.000000
#  75%                  NaN                NaN      0.000000     6.000000
#  max                  NaN                NaN      1.000000   235.000000
#
#          awards_nomination  revenue_category
#  count         2400.000000              2400
#  unique                NaN                 2
#  top                   NaN              High
#  freq                  NaN              1221
#  mean            12.698333               NaN
#  std             24.925965               NaN
#  min              0.000000               NaN
#  25%              1.000000               NaN
#  50%              5.000000               NaN
#  75%             12.000000               NaN
#  max            326.000000               NaN
#
#  [11 rows x 22 columns])

# %%
print(train_df["runtime"]. unique())
# Out:
# ['68 min' '160 min' '140 min' '118 min' '95 min' '88 min' '91 min'
#  '93 min' '109 min' '113 min' '85 min' '143 min' '104 min' '94 min'
#  '119 min' '112 min' '107 min' '97 min' '101 min' '130 min' '86 min'
#  '116 min' '105 min' '87 min' '100 min' '106 min' '90 min' '96 min'
#  '125 min' '108 min' '148 min' '92 min' '99 min' '181 min' '89 min'
#  '102 min' '127 min' '135 min' '110 min' '121 min' '120 min' '145 min'
#  '138 min' '133 min' '115 min' '122 min' '38 min' '117 min' '124 min'
#  '137 min' '114 min' '103 min' '186 min' '146 min' '83 min' '82 min'
#  '134 min' '129 min' '154 min' '41 min' '151 min' '80 min' '272 min'
#  '111 min' '158 min' '84 min' '98 min' '40 min' '192 min' '132 min'
#  '128 min' '123 min' '182 min' '156 min' '76 min' '78 min' '75 min'
#  '139 min' '153 min' '162 min' '142 min' '131 min' '126 min' '141 min'
#  '152 min' '175 min' '180 min' '157 min' '147 min' '566 min' '81 min'
#  '171 min' '136 min' '77 min' '150 min' '170 min' '183 min' '50 min'
#  '165 min' '155 min' '149 min' '168 min' '167 min' '72 min' '79 min'
#  '144 min' '163 min' '166 min' '178 min' '73 min' '65 min' '74 min'
#  '172 min' '187 min' '161 min' '59 min']

# %%
# Convert `runtime` to numeric by removing " min" and converting to integer
train_df["runtime"] = train_df["runtime"].astype(str).str.replace(" min", "").astype(float)

# Convert `ratings_imdb` to float by removing "/10"
train_df["ratings_imdb"] = train_df["ratings_imdb"].astype(str).str.replace("/10", "").astype(float)

# %%
# Convert `ratings_tomatoes` to percentage by removing "%" and converting to float
train_df["ratings_tomatoes"] = train_df["ratings_tomatoes"].astype(str).str.replace("%", "").astype(float)

# Convert `ratings_metacritic` to numeric by removing "/100" and converting to numeric
train_df["ratings_metacritic"] = train_df["ratings_metacritic"].astype(str).str.replace("/100", "")
train_df["ratings_metacritic"] = pd.to_numeric(train_df["ratings_metacritic"], errors="coerce")

# %%
# Convert release_date to datetime format and extract the year
train_df["release_date"] = pd.to_datetime(train_df["release_date"], errors='coerce')
train_df["release_year"] = train_df["release_date"].dt.year
# Out:
# /tmp/ipython-input-3845209372.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   train_df["release_date"] = pd.to_datetime(train_df["release_date"], errors='coerce')

# %%
# Fill missing numerical values with median
num_cols = ["writer_count", "comments", "likes", "overall_views", "dislikes", "ratings_metacritic", "release_year"]
for col in num_cols:
    train_df[col] = train_df[col].fillna(train_df[col].median())

# %%
# Fill missing categorical values with the most common value
cat_cols = ["censor_rating"]
for col in cat_cols:
    train_df[col] = train_df[col].fillna(train_df[col].mode()[0])

# %%
# Drop columns that are not useful for prediction
train_df = train_df.drop(columns=["title", "release_date", "dvd_release_date", "users_votes"])

# %%
# Display the cleaned dataset
train_df.head()
# Out:
#        country                                             genres  \
# 0          USA  Animation, Comedy, Family, Fantasy, Musical, M...
# 1        India                    Comedy, Drama, Musical, Romance
# 2  South Korea                                 Action, Drama, War
# 3          USA                 Action, Adventure, Drama, Thriller
# 4          USA                                    Comedy, Romance
#
#                  language  writer_count  title_adaption censor_rating  \
# 0                 English           3.0            True             G
# 1  Hindi, English, French           2.0            True     Not Rated
# 2                  Korean           4.0           False             R
# 3                 English           1.0           False             R
# 4                 English           1.0           False         PG-13
#
#    runtime  comments  likes  overall_views  dislikes  ratings_imdb  \
# 0     68.0      57.0  425.0       281652.0      30.0           6.4
# 1    160.0       9.0  124.0       127528.0      12.0           7.1
# 2    140.0     268.0  614.0       351123.0      18.0           8.1
# 3    118.0      57.0  425.0       281652.0      30.0           6.9
# 4     95.0     116.0  693.0       970306.0      36.0           6.1
#
#    ratings_tomatoes  ratings_metacritic  special_award  awards_win  \
# 0              80.0                  64              0           0
# 1              67.0                   0              0          22
# 2              80.0                  64              0          12
# 3              47.0                  53              0           3
# 4              25.0                   0              0           0
#
#    awards_nomination revenue_category  release_year
# 0                  1             High        2005.0
# 1                 92              Low        2013.0
# 2                  7              Low        2004.0
# 3                 16             High        2010.0
# 4                  0              Low        2007.0

# %% [markdown]
# ## **Exploratory Data Analysis**

# %%
# Plot distribution of runtime for high and low revenue categories
plt.figure(figsize=(10, 5))
sns.histplot(data=train_df, x="runtime", hue="revenue_category", kde=True, bins=30, alpha=0.7)
plt.title("Distribution of Movie Runtime by Revenue Category")
plt.xlabel("Runtime (minutes)")
plt.ylabel("Frequency")
plt.show()

# %%
# Boxplot for IMDB ratings by revenue category
plt.figure(figsize=(8, 5))
sns.boxplot(data=train_df, x="revenue_category", y="ratings_imdb")
plt.title("IMDB Ratings Distribution by Revenue Category")
plt.xlabel("Revenue Category")
plt.ylabel("IMDB Rating")
plt.show()

# %%
# Countplot for censor ratings by revenue category
plt.figure(figsize=(10, 5))
sns.countplot(data=train_df, x="censor_rating", hue="revenue_category", order=train_df["censor_rating"].value_counts().index)
plt.title("Censor Ratings Distribution by Revenue Category")
plt.xticks(rotation=45)
plt.xlabel("Censor Rating")
plt.ylabel("Count")
plt.show()

# %%
# Scatterplot of likes vs overall views by revenue category
plt.figure(figsize=(8, 5))
sns.scatterplot(data=train_df, x="likes", y="overall_views", hue="revenue_category", alpha=0.6)
plt.title("Likes vs. Overall Views by Revenue Category")
plt.xlabel("Likes")
plt.ylabel("Overall Views")
plt.xscale("log")
plt.yscale("log")
plt.show()

# %% [markdown]
# ## **Data Preprocessing**

# %%
# Encode categorical features
label_encoders = {}
for col in ["country", "genres", "language", "censor_rating", "revenue_category"]:
    le = LabelEncoder()
    train_df[col] = le.fit_transform(train_df[col])
    label_encoders[col] = le

# %%
# Define features and target variable
X = train_df.drop(columns=["revenue_category"])
y = train_df["revenue_category"]

# %%
# Split data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=0, stratify=y)

# %%
# Standardize numerical features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_val_scaled = scaler.transform(X_val)

# %%
# Train a Random Forest Classifier
rf_model = RandomForestClassifier(n_estimators=100, random_state=42)
rf_model.fit(X_train_scaled, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
# Predictions
y_pred = rf_model.predict(X_val_scaled)

# %%
# Evaluate model performance
accuracy = accuracy_score(y_val, y_pred)
f1 = f1_score(y_val, y_pred, average="weighted")
classification_rep = classification_report(y_val, y_pred)

# %%
print(" Model Accuracy: ", accuracy, '\n', "F1-score: ", f1, '\n', "Model Classification report:", '\n', classification_rep)
# Out:
#  Model Accuracy:  0.8166666666666667
#  F1-score:  0.8164210697240152
#  Model Classification report:
#                precision    recall  f1-score   support
#
#            0       0.80      0.85      0.82       244
#            1       0.83      0.78      0.81       236
#
#     accuracy                           0.82       480
#    macro avg       0.82      0.82      0.82       480
# weighted avg       0.82      0.82      0.82       480

# %% [markdown]
# #### **Model Performance Explanation**
# Accuracy: 81.67%,
#
# F1-score: 81.64%
#
# The model demonstrates strong performance in distinguishing between "High" and "Low" revenue categories.
# The precision and recall scores for both categories are balanced, indicating that the model does not overly favor one class.

# %% [markdown]
# ## **Prediction for Test File**

# %%
# Keep the title column separately for test submission
test_titles = test_df["title"]

# %%
# Apply the same preprocessing steps as the training set

# Convert `runtime` to numeric
test_df["runtime"] = test_df["runtime"].str.replace(" min", "").astype(float)

# Convert `ratings_imdb` to float by removing "/10"
test_df["ratings_imdb"] = test_df["ratings_imdb"].str.replace("/10", "").astype(float)

# Convert `ratings_tomatoes` to percentage by removing "%" and converting to float
test_df["ratings_tomatoes"] = test_df["ratings_tomatoes"].str.replace("%", "").astype(float)

# Convert `ratings_metacritic` to numeric by removing "/100".
test_df["ratings_metacritic"] = test_df["ratings_metacritic"].str.replace("/100", "", regex=True)
test_df["ratings_metacritic"] = pd.to_numeric(test_df["ratings_metacritic"], errors="coerce")

# %%
# Convert release_date to datetime and extract the year
test_df["release_date"] = pd.to_datetime(test_df["release_date"], errors='coerce')
test_df["release_year"] = test_df["release_date"].dt.year
# Out:
# /tmp/ipython-input-1878295207.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   test_df["release_date"] = pd.to_datetime(test_df["release_date"], errors='coerce')

# %%
# Fill missing numerical values with median from training set
for col in num_cols:
    test_df[col] = test_df[col].fillna(train_df[col].median())

# %%
# Fill missing categorical values with mode from training set
for col in cat_cols:
    test_df[col] = test_df[col].fillna(train_df[col].mode()[0])

# %%
# Encode categorical features using training label encoders
for col in ["country", "genres", "language", "censor_rating"]:
    test_df[col] = test_df[col].map(lambda x: label_encoders[col].transform([x])[0] if x in label_encoders[col].classes_ else -1)

# %%
# Fill missing release_year values with the median year
test_df["release_year"] = test_df["release_year"].fillna(train_df["release_year"].median())

# %%
# Drop unnecessary columns
test_df = test_df.drop(columns=["title", "release_date", "dvd_release_date", "users_votes"])

# %%
# Standardize numerical features using the training scaler
X_test_scaled = scaler.transform(test_df)

# %%
# Make predictions
test_predictions = rf_model.predict(X_test_scaled)

# %%
# Convert numerical predictions back to categorical values using inverse transform
test_predictions_labels = label_encoders["revenue_category"].inverse_transform(test_predictions)

# %%
# Create submission dataframe
submission_df = pd.DataFrame({"title": test_titles, "revenue_category": test_predictions_labels})

# Save to CSV
submission_file_path = "/content/drive/MyDrive/submissions.csv"
submission_df.to_csv(submission_file_path, index=False)
